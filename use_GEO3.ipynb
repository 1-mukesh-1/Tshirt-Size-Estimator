# %% [markdown]
# # Geometric Model

# %%
image_path = "./segmentation_testing/misc_images/kp_pose_2.jpg"

# %%
from get_size import suggest_size
import sys
import os
sys.path.append(os.path.dirname("geometric_model/"))

from geometric_model.body_measurement import BodyMeasurement as GM_Body_Measurement

# %%
measurements = GM_Body_Measurement(image_path, 181, False, True, False).execute()
val = measurements['real_measurements']['shoulder_width']
print(f"\n\n\nshoulder-breadth: {measurements['real_measurements']['shoulder_width']:.2f} cm")
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733833987.826010 9220288 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1733833988.085644 9220466 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733833988.255050 9220466 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733834031.581474 9220464 landmark_projection_calculator.cc:186] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# ...

# %%
sys.path.remove("geometric_model")

# %%
measurements
# Out:
# {'pixel_measurements': {'shoulder_width': 861.0743289635337,
#   'torso': 1815.1214835376722,
#   'left_hip_knee': 769.7077367416804,
#   'right_hip_knee': 799.7430837462741,
#   'left_knee_ankle': 526.7750943239439,
#   'right_knee_ankle': 554.8279012450618,
#   'total_height': 3169.6924685290082},
#  'real_measurements': {'shoulder_width': 49.170212911768246,
#   'torso': 103.6494839112219,
#   'left_hip_knee': 43.9528761018568,
#   'right_hip_knee': 45.66799448062949,
#   'left_knee_ankle': 30.08061287311011,
#   'right_knee_ankle': 31.682521608148598,
#   'total_height': 181.0,
#   'torso_height': 12.734042939734048}}

# %%
print("Size:",suggest_size(val))
# Out:
# Size: XL
