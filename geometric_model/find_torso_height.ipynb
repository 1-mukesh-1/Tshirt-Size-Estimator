# %%
image_path = "../segmentation_testing/misc_images/kp_pose_2.jpg"

# %%
get_garment_length(image_path)
# Out:
# Loading segmentation_training/best_model/best.onnx for ONNX Runtime inference...
# Preferring ONNX Runtime CoreMLExecutionProvider
# 2024-12-10 07:17:22.401212 [W:onnxruntime:, coreml_execution_provider.cc:107 GetCapability] CoreMLExecutionProvider::GetCapability, number of partitions supported by CoreML: 11 number of nodes in the graph: 400 number of nodes supported by CoreML: 386
# 0: 640x640 1 coat, 1 shirt, 627.9ms
# Speed: 76.4ms preprocess, 627.9ms inference, 128.6ms postprocess per image at shape (1, 3, 640, 640)
# 223
