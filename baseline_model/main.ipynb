# %%
from body_measurement import BodyMeasurement
import cv2

# %%
# Initialize with image path and actual height
measurements = BodyMeasurement(
    "./segmentation_testing/test2/testA/mask/0a15c19f92b0471622bc7251d9e1a603.png", 
    height_cm=175, 
    is_silhouette=True)


measurements = BodyMeasurement(
    "./segmentation_testing/test2/testA/mask/0a15c19f92b0471622bc7251d9e1a603.png", 
    height_cm=175)



# Get measurements (this will print them automatically)
results = measurements.execute()

visualized_image = measurements.visualize_measurements()
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1733713510.738230 8212274 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1733713510.957513 8212403 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733713511.066849 8212399 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Body Measurements:
# Shoulder Width: 45.1 cm
# Torso Height: 79.9 cm
# Chest Width: 40.6 cm
#
# Body Measurements:
# Shoulder Width: 45.1 cm
# Torso Height: 79.9 cm
# Chest Width: 40.6 cm
# ...

# %%
results
# Out:
# {'shoulder_width': 45.1, 'torso_height': 79.9, 'chest_width': 40.6}

# %%
measurements = BodyMeasurement("../segmentation_testing/test1/2d_models_male/male_0171.png", height_cm=175, is_silhouette=True)

# Get measurements (this will print them automatically)
results = measurements.execute()

visualized_image = measurements.visualize_measurements()
# Out:
# I0000 00:00:1733741764.024885 8495390 gl_context.cc:357] GL version: 2.1 (2.1 Metal - 89.3), renderer: Apple M2
# W0000 00:00:1733741764.248745 8532760 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1733741764.382796 8532759 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Body Measurements:
# Shoulder Width: 41.9 cm
# Torso Height: 75.4 cm
# Chest Width: 37.7 cm
#
# Body Measurements:
# Shoulder Width: 41.9 cm
# Torso Height: 75.4 cm
# Chest Width: 37.7 cm
